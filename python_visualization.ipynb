# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/saadkattan/python-visualization/blob/master/python_visualization.ipynb)

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as plt
# import numpy
import numpy as np

# %%
# generate graphs
x_axes = range(100)
x_1 = np.random.randint(0,100,100)
x_2 = np.random.randint(0,100,100)
x_3 = np.random.randint(0,100,100)
x_4 = np.random.randint(0,100,100)

# %%
# CASE 1: plots on common axes

# Plot in blue x_1 for the x_axes 
plt.plot(x_axes, x_1, color = 'blue')

# Plot in red x_2 for the x_axes 
plt.plot(x_axes, x_2, color = 'red')

# Display the plot
plt.show()

# %%
# CASE 2: plot different line plots on distinct axes

# Create plot axes for the first line plot
plt.axes([0.05, 0.05, 0.425, 0.9])

# Plot in blue x_1 for the x_axes 
plt.plot(x_axes, x_1, color = 'blue')

# Create plot axes for the second line plot
plt.axes([0.525, 0.05, 0.425, 0.9])

# Plot in red x_2 for the x_axes 
plt.plot(x_axes, x_2, color = 'red')


# Display the plot
plt.show()

# %%
# CASE 3: Using subplot:

# Create a figure with 2x2 subplot layout and make the top left subplot active
plt.subplot(2,2,1)

# Plot in blue x_1 for the x_axes 
plt.plot(x_axes, x_1, color = 'blue')
plt.title("x1")

# Make the top right subplot active in the current 2x2 subplot grid 
plt.subplot(2,2,2)

# Plot in red x_2 for the x_axes 
plt.plot(x_axes, x_2, color = 'red')
plt.title('x2')

# Make the bottom left subplot active in the current 2x2 subplot grid
plt.subplot(2,2,3)

## Plot in red x_3 for the x_axes 
plt.plot(x_axes, x_3, color = 'green')
plt.title('x3')

# Make the bottom right subplot active in the current 2x2 subplot grid
plt.subplot(2,2,4)

# Plot in red x_4 for the x_axes 
plt.plot(x_axes, x_4, color = 'black')
plt.title('x4')

# Improve the spacing between subplots and display them
plt.tight_layout() #graphs are cleaner.
plt.show()
