# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/saadkattan/python-visualization/blob/master/seaborn3.ipynb)

# %% [markdown]
# ##Seaborn #3
#
# ### Addtional knowaledge :
# - [`sns.jointplot`:](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
# - [`sns.heatmap`:](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
#
# Summary of all instructions used in this file for personal reference use.
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from google.colab import drive
# drive.mount('/content/drive')
# df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/python-visualization/New_Business_List_-_June.csv')
# print(df.columns.values)
# plt.subplot(2,1,1)
# sns.jointplot(x='bmi', y='charges', data =df, kind = "kde")
# print(df.head())
# sns.pairplot(df)
# sns.pairplot(df, kind='reg',  hue='sex')
# sns.heatmap
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/python-visualization/insurance.csv')
print(df.columns.values)
# Out:
# Mounted at /content/drive
# ['age' 'sex' 'bmi' 'children' 'smoker' 'region' 'charges']

# %%
# Generate a joint plot of 'hp' and 'mpg'
sns.jointplot(x='bmi', y='charges', data =df, kind = "kde")
# Display the plot
plt.show()

# %% [markdown]
# #### `kind` attribute:
# - `kind='scatter'` uses a scatter plot of the data points
# - `kind='reg'` uses a regression plot (default order 1)
# - `kind='resid'` uses a residual plot
# - `kind='kde'` uses a kernel density estimate of the joint distribution
# - `kind='hex' `uses a hexbin plot of the joint distribution
#
# ####  `sns.pairplot`
# - The function `sns.pairplot()`` constructs a grid of all joint plots pairwise from all pairs of (non-categorical) columns in a DataFrame.
# - An excellent way of visualizing the relationship between all continuous variables in a dataset.

# %%
# Print the first 5 rows of the DataFrame
print(df.head())
# Plot the pairwise joint distributions from the DataFrame 
sns.pairplot(df)
# Display the plot
plt.show()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.pairplot(df, kind='reg',  hue='sex') # default is kind='scatter'
